# %%
import pandas as pd

from sqlalchemy import create_engine

# %%
# create database connection
conn = create_engine('sqlite:///database_hm.sqlite', echo=False)

query_jeans = """
    SELECT *
    FROM vitrine
"""

df1 = pd.read_sql(query_jeans, conn)
df1
# Out:
#       product_id style_id color_id  product_name        color_name  \
# 0     1024256001  1024256      001    slim_jeans             black
# 1     1024256002  1024256      002    slim_jeans  light_denim_blue
# 2     1024256003  1024256      003    slim_jeans  light_denim_blue
# 3     1024256004  1024256      004    slim_jeans        denim_blue
# 4     1024256005  1024256      005    slim_jeans         dark_blue
# ...          ...      ...      ...           ...               ...
# 3455  0825927002  0825927      002  skinny_jeans        denim_blue
# 3456  0825927001  0825927      001  skinny_jeans  light_denim_blue
# 3457  0825927003  0825927      003  skinny_jeans             black
# 3458  0825927004  0825927      004  skinny_jeans             white
# 3459  0825927010  0825927      010  skinny_jeans        steel_blue
#
#       product_price  cotton  polyester  spandex  modal  elastomultiester  \
# 0             19.99    0.99       0.65     0.01    0.0               0.0
# ...
